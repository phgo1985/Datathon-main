# %%
from pathlib import Path
import sqlite3
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
caminho_db = Path.cwd() / "data" / "extraidos" / "dados.db"
print(caminho_db)
# Out:
# d:\0Viviana\1 FIAP\5 fase\datathon\app\data\extraidos\dados.db

# %%
conn = sqlite3.connect(caminho_db)

# %%
consulta_tabelas = "SELECT name FROM sqlite_master WHERE type='table';"
tabelas = pd.read_sql_query(consulta_tabelas, conn)
print("📋 Tabelas disponíveis no banco:")
print(tabelas)
# Out:
# 📋 Tabelas disponíveis no banco:
#          name
# 0  applicants
# 1   prospects
# 2       vagas

# %%
df_applicants = pd.read_sql_query("SELECT * FROM applicants", conn)
df_prospects = pd.read_sql_query("SELECT * FROM prospects", conn)
df_vagas = pd.read_sql_query("SELECT * FROM vagas", conn)

# %%
df_vagas.dtypes
# Out:
# codigo                                                  object
# informacoes_basicas_data_requicisao                     object
# informacoes_basicas_limite_esperado_para_contratacao    object
# informacoes_basicas_titulo_vaga                         object
# informacoes_basicas_vaga_sap                            object
# informacoes_basicas_cliente                             object
# informacoes_basicas_solicitante_cliente                 object
# informacoes_basicas_empresa_divisao                     object
# informacoes_basicas_requisitante                        object
# informacoes_basicas_analista_responsavel                object
# informacoes_basicas_tipo_contratacao                    object
# informacoes_basicas_prazo_contratacao                   object
# informacoes_basicas_objetivo_vaga                       object
# informacoes_basicas_prioridade_vaga                     object
# informacoes_basicas_origem_vaga                         object
# ...

# %%
df_applicants.dtypes
# Out:
# codigo                                              object
# infos_basicas_telefone_recado                       object
# infos_basicas_telefone                              object
# infos_basicas_objetivo_profissional                 object
# infos_basicas_data_criacao                          object
# infos_basicas_inserido_por                          object
# infos_basicas_email                                 object
# infos_basicas_local                                 object
# infos_basicas_sabendo_de_nos_por                    object
# infos_basicas_data_atualizacao                      object
# infos_basicas_codigo_profissional                   object
# infos_basicas_nome                                  object
# informacoes_pessoais_data_aceite                    object
# informacoes_pessoais_nome                           object
# informacoes_pessoais_cpf                            object
# informacoes_pessoais_fonte_indicacao                object
# ...

# %%
df_prospects.dtypes
# Out:
# codigo_vaga           object
# codigo                object
# comentario            object
# data_candidatura      object
# modalidade            object
# nome                  object
# recrutador            object
# situacao_candidado    object
# titulo                object
# ultima_atualizacao    object
# dtype: object

# %%
df_vagas.head(3)
# Out:
#   codigo informacoes_basicas_data_requicisao  \
# 0   5185                          04-05-2021
# 1   5184                          04-05-2021
# 2   5183                          04-05-2021
#
#   informacoes_basicas_limite_esperado_para_contratacao  \
# 0                                         00-00-0000
# 1                                         00-00-0000
# 2                                         00-00-0000
#
#   informacoes_basicas_titulo_vaga informacoes_basicas_vaga_sap  \
# 0                Operation Lead -                          Não
# 1          Consultor PP/QM Sênior                          Não
# 2           ANALISTA PL/JR C/ SQL                          Não
#
#   informacoes_basicas_cliente informacoes_basicas_solicitante_cliente  \
# 0    Morris, Moran and Dodson                   Dra. Catarina Marques
# 1    Morris, Moran and Dodson                   Dra. Catarina Marques
# 2    Morris, Moran and Dodson                   Dra. Catarina Marques
#
# ...

# %%
df_prospects.head(3)
# Out:
#   codigo_vaga codigo                                         comentario  \
# 0        4530  25632               Encaminhado para  - PJ R$ 72,00/hora
# 1        4530  25529  encaminhado para  - R$ 6.000,00 – CLT Full , n...
# 2        4531  25364                         Data de Inicio: 12/04/2021
#
#   data_candidatura modalidade                      nome         recrutador  \
# 0       25/03/2021                          José Vieira  Ana Lívia Moreira
# 1       22/03/2021             Srta. Isabela Cavalcante  Ana Lívia Moreira
# 2       17/03/2021                Sra. Yasmin Fernandes   Juliana Cassiano
#
#             situacao_candidado  \
# 0  Encaminhado ao Requisitante
# 1  Encaminhado ao Requisitante
# 2     Contratado pela Decision
#
#                                               titulo ultima_atualizacao
# 0                                CONSULTOR CONTROL M         25/03/2021
# 1                                CONSULTOR CONTROL M         23/03/2021
# ...

# %%
df_applicants.head(3)
# Out:
#   codigo infos_basicas_telefone_recado infos_basicas_telefone  \
# 0  31000                                      (11) 97048-2708
# 1  31001                                      (11) 93723-4396
# 2  31002                                      (11) 92399-9824
#
#   infos_basicas_objetivo_profissional infos_basicas_data_criacao  \
# 0                                            10-11-2021 07:29:49
# 1             Analista Administrativo        10-11-2021 08:56:16
# 2         Administrativo | Financeiro        10-11-2021 09:01:00
#
#   infos_basicas_inserido_por                infos_basicas_email  \
# 0               Luna Correia       carolina_aparecida@gmail.com
# 1              Laura Pacheco           eduardo_rios@hotmail.com
# 2              Laura Pacheco  pedro_henrique_carvalho@gmail.com
#
#     infos_basicas_local infos_basicas_sabendo_de_nos_por  \
# 0
# 1  São Paulo, São Paulo                           Outros
# 2  São Paulo, São Paulo                          Anúncio
#
# ...

# %%
df_applicants.loc[df_applicants['informacoes_pessoais_nome'] == 'Carolina Aparecida', ['codigo', 'infos_basicas_codigo_profissional', 'informacoes_pessoais_nome', 'infos_basicas_email']]
# Out:
#   codigo infos_basicas_codigo_profissional informacoes_pessoais_nome  \
# 0  31000                             31000        Carolina Aparecida
#
#             infos_basicas_email
# 0  carolina_aparecida@gmail.com

# %%
df_prospects[df_prospects['codigo_vaga'] == "7422"]
# Out:
#       codigo_vaga codigo                                         comentario  \
# 12350        7422  32332
# 12351        7422  32028
# 12352        7422  31966
# 12353        7422  31857
# 12354        7422  31810
# 12355        7422  31601
# 12356        7422  31211
# 12357        7422  31165
# 12358        7422  31101
# 12359        7422  31097
# 12360        7422  31066                  Candidata fora do perfil da vaga.
# 12361        7422  31058  Pretensão CLT R$2.200,00 Atuação presencial ou...
# 12362        7422  31011  Pretensão CLT R$1.800,00 Atuação presencial ou...
# 12363        7422  31009               Sem interesse em vaga de assistente.
# 12364        7422  31003
# 12365        7422  31000         Pretensão salarial R$ 2K CLT / Imediata /
# 12366        7422  30999
# 12367        7422  30997      Pretensão salarial R$ 1.800 CLT / Imediata /
# 12368        7422  30995  Pretensão CLT R$1.600,00 Atuação presencial ou...
# ...

# %%
df_vagas[df_vagas['codigo'] == '7422']
# Out:
#      codigo informacoes_basicas_data_requicisao  \
# 5299   7422                          09-11-2021
#
#      informacoes_basicas_limite_esperado_para_contratacao  \
# 5299                                         00-00-0000
#
#                     informacoes_basicas_titulo_vaga  \
# 5299  Assistente Administrativo/Operação - 12416476
#
#      informacoes_basicas_vaga_sap informacoes_basicas_cliente  \
# 5299                          Não    Wade, Bernard and Bailey
#
#      informacoes_basicas_solicitante_cliente  \
# 5299                       Dr. Raul Monteiro
#
#      informacoes_basicas_empresa_divisao informacoes_basicas_requisitante  \
# 5299                  Decision São Paulo                  Cecília Freitas
#
#      informacoes_basicas_analista_responsavel  ...  \
# 5299                        Maria Clara Pires  ...
#
#                          perfil_vaga_demais_observacoes  \
# 5299  Budgeted Rate - indicate currency and type (ho...
#
# ...

# %%
df_applicants[df_applicants['infos_basicas_codigo_profissional'] == "31000"]
# Out:
#   codigo infos_basicas_telefone_recado infos_basicas_telefone  \
# 0  31000                                      (11) 97048-2708
#
#   infos_basicas_objetivo_profissional infos_basicas_data_criacao  \
# 0                                            10-11-2021 07:29:49
#
#   infos_basicas_inserido_por           infos_basicas_email  \
# 0               Luna Correia  carolina_aparecida@gmail.com
#
#   infos_basicas_local infos_basicas_sabendo_de_nos_por  \
# 0
#
#   infos_basicas_data_atualizacao  ... cargo_atual_id_ibrati  \
# 0            10-11-2021 07:29:49  ...                  None
#
#   cargo_atual_email_corporativo cargo_atual_cargo_atual  \
# 0                          None                    None
#
#   cargo_atual_projeto_atual cargo_atual_cliente cargo_atual_unidade  \
# 0                      None                None                None
#
#   cargo_atual_data_admissao cargo_atual_data_ultima_promocao  \
# 0                      None                             None
#
# ...

# %%
df_applicants[df_applicants['informacoes_pessoais_nome'] == "Carolina Aparecida"]\
    .to_csv("carolina_aparecida.csv", index=False, encoding="utf-8-sig", sep=",")

# %%
df_applicants[['codigo','informacoes_pessoais_nome']]
# Out:
#       codigo informacoes_pessoais_nome
# 0      31000        Carolina Aparecida
# 1      31001              Eduardo Rios
# 2      31002   Pedro Henrique Carvalho
# 3      31003            Thiago Barbosa
# 4      31004           Diogo das Neves
# ...      ...                       ...
# 42477   5995          Gabrielly Novaes
# 42478   5996          Sr. Gabriel Rios
# 42479   5997      Dr. Mathias da Cunha
# 42480   5998              Bruna Vieira
# 42481   5999           Heitor Mendonça
#
# [42482 rows x 2 columns]

# %%
conn.close()
